# %% [markdown]
# ## Demographic and Medical Condition data analysis + ML exploration

# %% [markdown]
# Data_Source = https://datosabiertos.salud.gob.mx/gobmx/salud/datos_abiertos/datos_abiertos_covid19.zip

# %%
# Initial imports
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import hvplot.pandas
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("./Resources/220614COVID19MEXICO.csv")
df.info()
# Out:
# C:\Users\yuanj\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16192035 entries, 0 to 16192034
# Data columns (total 40 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   FECHA_ACTUALIZACION    object
#  1   ID_REGISTRO            object
#  2   ORIGEN                 int64
#  3   SECTOR                 int64
#  4   ENTIDAD_UM             int64
#  5   SEXO                   int64
#  6   ENTIDAD_NAC            int64
#  7   ENTIDAD_RES            int64
#  8   MUNICIPIO_RES          int64
#  9   TIPO_PACIENTE          int64
#  10  FECHA_INGRESO          object
#  11  FECHA_SINTOMAS         object
#  12  FECHA_DEF              object
#  13  INTUBADO               int64
#  14  NEUMONIA               int64
#  15  EDAD                   int64
#  16  NACIONALIDAD           int64
#  17  EMBARAZO               int64
#  18  HABLA_LENGUA_INDIG     int64
#  19  INDIGENA               int64
#  20  DIABETES               int64
#  21  EPOC                   int64
#  22  ASMA                   int64
#  23  INMUSUPR               int64
#  24  HIPERTENSION           int64
#  25  OTRA_COM               int64
#  26  CARDIOVASCULAR         int64
#  27  OBESIDAD               int64
#  28  RENAL_CRONICA          int64
#  29  TABAQUISMO             int64
#  30  OTRO_CASO              int64
#  31  TOMA_MUESTRA_LAB       int64
#  32  RESULTADO_LAB          int64
#  33  TOMA_MUESTRA_ANTIGENO  int64
#  34  RESULTADO_ANTIGENO     int64
#  35  CLASIFICACION_FINAL    int64
#  36  MIGRANTE               int64
#  37  PAIS_NACIONALIDAD      object
#  38  PAIS_ORIGEN            object
#  39  UCI                    int64
# dtypes: int64(33), object(7)
# memory usage: 4.8+ GB

# %%
cols=[]
for x in df.columns:
    cols.append(x)

# %%
cols
# Out:
# ['FECHA_ACTUALIZACION',
#  'ID_REGISTRO',
#  'ORIGEN',
#  'SECTOR',
#  'ENTIDAD_UM',
#  'SEXO',
#  'ENTIDAD_NAC',
#  'ENTIDAD_RES',
#  'MUNICIPIO_RES',
#  'TIPO_PACIENTE',
#  'FECHA_INGRESO',
#  'FECHA_SINTOMAS',
#  'FECHA_DEF',
#  'INTUBADO',
#  'NEUMONIA',
#  'EDAD',
#  'NACIONALIDAD',
#  'EMBARAZO',
#  'HABLA_LENGUA_INDIG',
#  'INDIGENA',
#  'DIABETES',
#  'EPOC',
#  'ASMA',
#  'INMUSUPR',
#  'HIPERTENSION',
#  'OTRA_COM',
#  'CARDIOVASCULAR',
#  'OBESIDAD',
#  'RENAL_CRONICA',
#  'TABAQUISMO',
#  'OTRO_CASO',
#  'TOMA_MUESTRA_LAB',
#  'RESULTADO_LAB',
#  'TOMA_MUESTRA_ANTIGENO',
#  'RESULTADO_ANTIGENO',
#  'CLASIFICACION_FINAL',
#  'MIGRANTE',
#  'PAIS_NACIONALIDAD',
#  'PAIS_ORIGEN',
#  'UCI']

# %%
# Update Columns in English
new_cols = ['DATE UPDATE',
 'REGISTRATION_ID',
 'SOURCE',
 'SECTOR',
 'ENTITY_UM',
 'SEX',
 'ENTITY_NAC',
 'ENTITY_RES',
 'MUNICIPALITY_RES',
 'TYPE_PATIENT',
 'ADMISSION DATE',
 'DATE_SYMPTOMS',
 'DATE_DEF',
 'INTUBATED',
 'PNEUMONIA',
 'AGE',
 'NATIONALITY',
 'PREGNANCY',
 'SPEAK_LANGUAGE_INDIG',
 'INDIGENOUS',
 'DIABETES',
 'COPD',
 'ASTHMA',
 'INMUSUPR',
 'HYPERTENSION',
 'OTHER_COM',
 'CARDIOVASCULAR',
 'OBESITY',
 'RENAL_CHRONIC',
 'SMOKING',
 'ANOTHER CASE',
 'TAKE_LAB_SAMPLE',
 'LAB_RESULT',
 'TAKE_SAMPLE_ANTIGEN',
 'RESULT_ANTIGEN',
 'FINAL_CLASSIFICATION',
 'MIGRANT',
 'COUNTRY_NATIONALITY',
 'COUNTRY OF ORIGIN',
 'ICU']

# %%
df.columns = new_cols
df.head()
# Out:
#   DATE UPDATE REGISTRATION_ID  SOURCE  SECTOR  ENTITY_UM  SEX  ENTITY_NAC  \
# 0  2022-06-14          z24953       1      12          9    1           9
# 1  2022-06-14          z23d9d       1      12         22    2          24
# 2  2022-06-14          z49a69       1      12         23    1          23
# 3  2022-06-14          z482b8       2      12          9    2           9
# 4  2022-06-14          z3bf80       2      12          8    2           8
#
#    ENTITY_RES  MUNICIPALITY_RES  TYPE_PATIENT  ... ANOTHER CASE  \
# 0           9                10             1  ...            1
# 1          22                 9             1  ...            2
# 2          23                 4             2  ...            1
# 3           9                12             1  ...            2
# 4           8                37             1  ...            2
#
#   TAKE_LAB_SAMPLE LAB_RESULT  TAKE_SAMPLE_ANTIGEN  RESULT_ANTIGEN  \
# 0               1          2                    2              97
# 1               2         97                    2              97
# 2               2         97                    2              97
# 3               2         97                    2              97
# 4               1          1                    2              97
#
#    FINAL_CLASSIFICATION  MIGRANT  COUNTRY_NATIONALITY  COUNTRY OF ORIGIN  ICU
# 0                     7       99               México                 97   97
# 1                     6       99               México                 97   97
# 2                     2       99               México                 97    1
# 3                     1       99               México                 97   97
# 4                     3       99               México                 97   97
#
# [5 rows x 40 columns]

# %%
# Drop date update, registration ID,SOURCE,SECTOR,ENTITY_UM,MUNICIPALITY_RES
df1 = df.drop(columns = ['DATE UPDATE','REGISTRATION_ID',"SOURCE","SECTOR","ENTITY_UM",'MUNICIPALITY_RES'])
df1
# Out:
#           SEX  ENTITY_NAC  ENTITY_RES  TYPE_PATIENT ADMISSION DATE  \
# 0           1           9           9             1     2020-10-15
# 1           2          24          22             1     2021-01-05
# 2           1          23          23             2     2020-07-20
# 3           2           9           9             1     2020-10-16
# 4           2           8           8             1     2020-07-28
# ...       ...         ...         ...           ...            ...
# 16192030    2          13          15             1     2022-03-04
# 16192031    1          15          15             1     2022-03-04
# 16192032    2          15          15             1     2022-03-05
# 16192033    1           9          15             1     2022-03-05
# 16192034    2          15          15             2     2022-03-05
#
#          DATE_SYMPTOMS    DATE_DEF  INTUBATED  PNEUMONIA  AGE  ...  \
# 0           2020-10-15  9999-99-99         97          2   40  ...
# 1           2021-01-05  9999-99-99         97          2   29  ...
# 2           2020-07-17  2020-07-21          1          1   66  ...
# 3           2020-10-16  9999-99-99         97          2   41  ...
# 4           2020-07-20  9999-99-99         97          2   35  ...
# ...                ...         ...        ...        ...  ...  ...
# 16192030    2022-03-04  9999-99-99         97         99   25  ...
# 16192031    2022-03-04  9999-99-99         97         99   23  ...
# 16192032    2022-03-05  9999-99-99         97         99   44  ...
# 16192033    2022-03-05  9999-99-99         97         99   48  ...
# 16192034    2022-03-05  9999-99-99          2         99    0  ...
#
#           ANOTHER CASE  TAKE_LAB_SAMPLE  LAB_RESULT  TAKE_SAMPLE_ANTIGEN  \
# 0                    1                1           2                    2
# 1                    2                2          97                    2
# 2                    1                2          97                    2
# 3                    2                2          97                    2
# 4                    2                1           1                    2
# ...                ...              ...         ...                  ...
# 16192030            99                2          97                    2
# 16192031            99                2          97                    2
# 16192032            99                2          97                    2
# 16192033            99                2          97                    2
# 16192034            99                2          97                    2
#
#           RESULT_ANTIGEN  FINAL_CLASSIFICATION  MIGRANT  COUNTRY_NATIONALITY  \
# 0                     97                     7       99               México
# 1                     97                     6       99               México
# 2                     97                     2       99               México
# 3                     97                     1       99               México
# 4                     97                     3       99               México
# ...                  ...                   ...      ...                  ...
# 16192030              97                     6       99               México
# 16192031              97                     6       99               México
# 16192032              97                     6       99               México
# 16192033              97                     6       99               México
# 16192034              97                     6       99               México
#
#           COUNTRY OF ORIGIN  ICU
# 0                        97   97
# 1                        97   97
# 2                        97    1
# 3                        97   97
# 4                        97   97
# ...                     ...  ...
# 16192030                 97   97
# 16192031                 97   97
# 16192032                 97   97
# 16192033                 97   97
# 16192034                 97    2
#
# [16192035 rows x 34 columns]

# %%
df1[df1['TAKE_LAB_SAMPLE']==2].groupby(['RESULT_ANTIGEN']).count()
# Out:
#                     SEX  ENTITY_NAC  ENTITY_RES  TYPE_PATIENT  ADMISSION DATE  \
# RESULT_ANTIGEN
# 1               3155285     3155285     3155285       3155285         3155285
# 2               6725173     6725173     6725173       6725173         6725173
# 97               582153      582153      582153        582153          582153
#
#                 DATE_SYMPTOMS  DATE_DEF  INTUBATED  PNEUMONIA      AGE  ...  \
# RESULT_ANTIGEN                                                          ...
# 1                     3155285   3155285    3155285    3155285  3155285  ...
# 2                     6725173   6725173    6725173    6725173  6725173  ...
# 97                     582153    582153     582153     582153   582153  ...
#
#                 SMOKING  ANOTHER CASE  TAKE_LAB_SAMPLE  LAB_RESULT  \
# RESULT_ANTIGEN
# 1               3155285       3155285          3155285     3155285
# 2               6725173       6725173          6725173     6725173
# 97               582153        582153           582153      582153
#
#                 TAKE_SAMPLE_ANTIGEN  FINAL_CLASSIFICATION  MIGRANT  \
# RESULT_ANTIGEN
# 1                           3155285               3155285  3155285
# 2                           6725173               6725173  6725173
# 97                           582153                582153   582153
#
#                 COUNTRY_NATIONALITY  COUNTRY OF ORIGIN      ICU
# RESULT_ANTIGEN
# 1                           3155285            3155285  3155285
# 2                           6725173            6725173  6725173
# 97                           582153             582153   582153
#
# [3 rows x 33 columns]

# %%
# Drop who didn't do Lab test and don't have an Antigen result
reqd_Index = df1[(df1['TAKE_LAB_SAMPLE']==2) & (df1['RESULT_ANTIGEN'] == 97)].index.tolist()

# %%
len(reqd_Index)
# Out:
# 582153

# %%
df2 = df1.drop(index = reqd_Index)

# %%
# Is the data valid? Age more than 121? remove edge cases;
reqd_Index2 = df2[(df2['AGE']>121) & (df2['ANOTHER CASE']==99)].index.tolist()

# %%
len(reqd_Index2)
# Out:
# 50

# %%
df3 = df2.drop(index = reqd_Index2)

# %%
# Invalid entry, result not attribute to COVID, we should drop it.
df3[(df3['LAB_RESULT']==4) & (df3['RESULT_ANTIGEN']==97) ].groupby(['FINAL_CLASSIFICATION']).count()
# Out:
#                         SEX  ENTITY_NAC  ENTITY_RES  TYPE_PATIENT  \
# FINAL_CLASSIFICATION
# 1                     14078       14078       14078         14078
# 2                      2947        2947        2947          2947
# 4                     11661       11661       11661         11661
# 5                     90944       90944       90944         90944
# 6                     88144       88144       88144         88144
#
#                       ADMISSION DATE  DATE_SYMPTOMS  DATE_DEF  INTUBATED  \
# FINAL_CLASSIFICATION
# 1                              14078          14078     14078      14078
# 2                               2947           2947      2947       2947
# 4                              11661          11661     11661      11661
# 5                              90944          90944     90944      90944
# 6                              88144          88144     88144      88144
#
#                       PNEUMONIA    AGE  ...  SMOKING  ANOTHER CASE  \
# FINAL_CLASSIFICATION                    ...
# 1                         14078  14078  ...    14078         14078
# 2                          2947   2947  ...     2947          2947
# 4                         11661  11661  ...    11661         11661
# 5                         90944  90944  ...    90944         90944
# 6                         88144  88144  ...    88144         88144
#
#                       TAKE_LAB_SAMPLE  LAB_RESULT  TAKE_SAMPLE_ANTIGEN  \
# FINAL_CLASSIFICATION
# 1                               14078       14078                14078
# 2                                2947        2947                 2947
# 4                               11661       11661                11661
# 5                               90944       90944                90944
# 6                               88144       88144                88144
#
#                       RESULT_ANTIGEN  MIGRANT  COUNTRY_NATIONALITY  \
# FINAL_CLASSIFICATION
# 1                              14078    14078                14078
# 2                               2947     2947                 2947
# 4                              11661    11661                11661
# 5                              90944    90944                90944
# 6                              88144    88144                88144
#
#                       COUNTRY OF ORIGIN    ICU
# FINAL_CLASSIFICATION
# 1                                 14078  14078
# 2                                  2947   2947
# 4                                 11661  11661
# 5                                 90944  90944
# 6                                 88144  88144
#
# [5 rows x 33 columns]

# %%
reqd_Index3 = df3[(df3['LAB_RESULT']==4) & (df3['RESULT_ANTIGEN']==97) &(df3['FINAL_CLASSIFICATION'] != 1) &(df3['FINAL_CLASSIFICATION'] != 2) ].index.tolist()

# %%
len(reqd_Index3)
# Out:
# 190749

# %%
df4 = df3.drop(index = reqd_Index3)

# %%
df4 = df4.drop(columns = 'ENTITY_NAC')

# %%
sample_df = df4.sample(20000)
sample_df= sample_df.reset_index(drop=True)

# %%
sample_df.sort_values('ADMISSION DATE',ascending = True)
# Out:
#        SEX  ENTITY_RES  TYPE_PATIENT ADMISSION DATE DATE_SYMPTOMS    DATE_DEF  \
# 11440    2           9             1     2020-01-27    2020-01-26  9999-99-99
# 11484    1          29             1     2020-01-29    2020-01-28  9999-99-99
# 16146    1          30             2     2020-02-05    2020-02-05  9999-99-99
# 6780     2          25             2     2020-02-09    2020-02-09  9999-99-99
# 4964     2          15             2     2020-02-09    2020-02-08  9999-99-99
# ...    ...         ...           ...            ...           ...         ...
# 19693    1          15             1     2022-06-13    2022-06-11  9999-99-99
# 3242     1           9             1     2022-06-13    2022-06-10  9999-99-99
# 15205    1          11             1     2022-06-13    2022-06-10  9999-99-99
# 13306    1          19             1     2022-06-13    2022-06-12  9999-99-99
# 14479    1          16             1     2022-06-13    2022-06-13  9999-99-99
#
#        INTUBATED  PNEUMONIA  AGE  NATIONALITY  ...  ANOTHER CASE  \
# 11440         97         99   15            1  ...             2
# 11484         97         99   27            1  ...            99
# 16146         99         99   28            1  ...            99
# 6780          99         99    1            1  ...            99
# 4964          99         99    1            1  ...             2
# ...          ...        ...  ...          ...  ...           ...
# 19693         97          2   42            1  ...             2
# 3242          97          2   76            1  ...             1
# 15205         97          2    5            1  ...             2
# 13306         97          2   30            1  ...             2
# 14479         97          2   48            1  ...             1
#
#        TAKE_LAB_SAMPLE  LAB_RESULT  TAKE_SAMPLE_ANTIGEN  RESULT_ANTIGEN  \
# 11440                1           2                    2              97
# 11484                1           2                    2              97
# 16146                1           2                    2              97
# 6780                 1           2                    2              97
# 4964                 1           2                    2              97
# ...                ...         ...                  ...             ...
# 19693                1           3                    1               1
# 3242                 2          97                    1               2
# 15205                2          97                    1               2
# 13306                2          97                    1               1
# 14479                2          97                    1               1
#
#        FINAL_CLASSIFICATION  MIGRANT  COUNTRY_NATIONALITY  COUNTRY OF ORIGIN  \
# 11440                     7       99               México                 97
# 11484                     7       99               México                 97
# 16146                     7       99               México                 97
# 6780                      7       99               México                 97
# 4964                      7       99               México                 97
# ...                     ...      ...                  ...                ...
# 19693                     3       99               México                 97
# 3242                      7       99               México                 97
# 15205                     7       99               México                 97
# 13306                     3       99               México                 97
# 14479                     3       99               México                 97
#
#        ICU
# 11440   97
# 11484   97
# 16146   99
# 6780    99
# 4964    99
# ...    ...
# 19693   97
# 3242    97
# 15205   97
# 13306   97
# 14479   97
#
# [20000 rows x 33 columns]

# %%
sample_df.groupby(['DATE_DEF']).count()
# Out:
#               SEX  ENTITY_RES  TYPE_PATIENT  ADMISSION DATE  DATE_SYMPTOMS  \
# DATE_DEF
# 2020-04-04      1           1             1               1              1
# 2020-04-13      1           1             1               1              1
# 2020-04-17      1           1             1               1              1
# 2020-04-18      1           1             1               1              1
# 2020-04-20      1           1             1               1              1
# ...           ...         ...           ...             ...            ...
# 2022-03-21      1           1             1               1              1
# 2022-03-23      1           1             1               1              1
# 2022-03-26      1           1             1               1              1
# 2022-04-16      1           1             1               1              1
# 9999-99-99  19471       19471         19471           19471          19471
#
#             INTUBATED  PNEUMONIA    AGE  NATIONALITY  PREGNANCY  ...  \
# DATE_DEF                                                         ...
# 2020-04-04          1          1      1            1          1  ...
# 2020-04-13          1          1      1            1          1  ...
# 2020-04-17          1          1      1            1          1  ...
# 2020-04-18          1          1      1            1          1  ...
# 2020-04-20          1          1      1            1          1  ...
# ...               ...        ...    ...          ...        ...  ...
# 2022-03-21          1          1      1            1          1  ...
# 2022-03-23          1          1      1            1          1  ...
# 2022-03-26          1          1      1            1          1  ...
# 2022-04-16          1          1      1            1          1  ...
# 9999-99-99      19471      19471  19471        19471      19471  ...
#
#             ANOTHER CASE  TAKE_LAB_SAMPLE  LAB_RESULT  TAKE_SAMPLE_ANTIGEN  \
# DATE_DEF
# 2020-04-04             1                1           1                    1
# 2020-04-13             1                1           1                    1
# 2020-04-17             1                1           1                    1
# 2020-04-18             1                1           1                    1
# 2020-04-20             1                1           1                    1
# ...                  ...              ...         ...                  ...
# 2022-03-21             1                1           1                    1
# 2022-03-23             1                1           1                    1
# 2022-03-26             1                1           1                    1
# 2022-04-16             1                1           1                    1
# 9999-99-99         19471            19471       19471                19471
#
#             RESULT_ANTIGEN  FINAL_CLASSIFICATION  MIGRANT  \
# DATE_DEF
# 2020-04-04               1                     1        1
# 2020-04-13               1                     1        1
# 2020-04-17               1                     1        1
# 2020-04-18               1                     1        1
# 2020-04-20               1                     1        1
# ...                    ...                   ...      ...
# 2022-03-21               1                     1        1
# 2022-03-23               1                     1        1
# 2022-03-26               1                     1        1
# 2022-04-16               1                     1        1
# 9999-99-99           19471                 19471    19471
#
#             COUNTRY_NATIONALITY  COUNTRY OF ORIGIN    ICU
# DATE_DEF
# 2020-04-04                    1                  1      1
# 2020-04-13                    1                  1      1
# 2020-04-17                    1                  1      1
# 2020-04-18                    1                  1      1
# 2020-04-20                    1                  1      1
# ...                         ...                ...    ...
# 2022-03-21                    1                  1      1
# 2022-03-23                    1                  1      1
# 2022-03-26                    1                  1      1
# 2022-04-16                    1                  1      1
# 9999-99-99                19471              19471  19471
#
# [339 rows x 32 columns]

# %%
# Encode the target: people with deceased date as 1, and people alive as 0
sample_df.loc[sample_df['DATE_DEF'] == "9999-99-99", 'Target'] = int(0) 
sample_df.loc[sample_df['DATE_DEF'] != "9999-99-99", 'Target'] = int(1)

# %%
sample_df.groupby(['Target']).count()
# Out:
#           SEX  ENTITY_RES  TYPE_PATIENT  ADMISSION DATE  DATE_SYMPTOMS  \
# Target
# 0.0     19471       19471         19471           19471          19471
# 1.0       529         529           529             529            529
#
#         DATE_DEF  INTUBATED  PNEUMONIA    AGE  NATIONALITY  ...  ANOTHER CASE  \
# Target                                                      ...
# 0.0        19471      19471      19471  19471        19471  ...         19471
# 1.0          529        529        529    529          529  ...           529
#
#         TAKE_LAB_SAMPLE  LAB_RESULT  TAKE_SAMPLE_ANTIGEN  RESULT_ANTIGEN  \
# Target
# 0.0               19471       19471                19471           19471
# 1.0                 529         529                  529             529
#
#         FINAL_CLASSIFICATION  MIGRANT  COUNTRY_NATIONALITY  COUNTRY OF ORIGIN  \
# Target
# 0.0                    19471    19471                19471              19471
# 1.0                      529      529                  529                529
#
#           ICU
# Target
# 0.0     19471
# 1.0       529
#
# [2 rows x 33 columns]

# %%
sample_df
# Out:
#        SEX  ENTITY_RES  TYPE_PATIENT ADMISSION DATE DATE_SYMPTOMS    DATE_DEF  \
# 0        1          21             2     2020-12-21    2020-12-12  2020-12-21
# 1        1          30             1     2022-03-31    2022-03-30  9999-99-99
# 2        2          25             1     2022-01-17    2022-01-14  9999-99-99
# 3        1           9             1     2021-07-23    2021-07-21  9999-99-99
# 4        1          16             1     2021-04-09    2021-04-09  9999-99-99
# ...    ...         ...           ...            ...           ...         ...
# 19995    1           3             1     2021-07-28    2021-07-26  9999-99-99
# 19996    1           6             1     2021-08-12    2021-08-09  9999-99-99
# 19997    2          27             1     2021-08-24    2021-08-23  9999-99-99
# 19998    1          26             1     2022-01-25    2022-01-20  9999-99-99
# 19999    2           5             1     2021-10-26    2021-10-25  9999-99-99
#
#        INTUBATED  PNEUMONIA  AGE  NATIONALITY  ...  TAKE_LAB_SAMPLE  \
# 0              2          1   50            1  ...                1
# 1             97          2    9            1  ...                2
# 2             97          2   47            1  ...                2
# 3             97          2   59            1  ...                2
# 4             97          2   21            1  ...                2
# ...          ...        ...  ...          ...  ...              ...
# 19995         97          2   36            1  ...                2
# 19996         97          2   29            1  ...                2
# 19997         97          2   71            1  ...                2
# 19998         97          2   48            1  ...                2
# 19999         97          2   38            1  ...                2
#
#        LAB_RESULT  TAKE_SAMPLE_ANTIGEN  RESULT_ANTIGEN  FINAL_CLASSIFICATION  \
# 0               2                    2              97                     7
# 1              97                    1               2                     7
# 2              97                    1               2                     7
# 3              97                    1               2                     7
# 4              97                    1               2                     7
# ...           ...                  ...             ...                   ...
# 19995          97                    1               1                     3
# 19996          97                    1               1                     3
# 19997          97                    1               2                     7
# 19998          97                    1               1                     3
# 19999          97                    1               1                     3
#
#        MIGRANT  COUNTRY_NATIONALITY  COUNTRY OF ORIGIN  ICU  Target
# 0           99               México                 97    2     1.0
# 1           99               México                 97   97     0.0
# 2           99               México                 97   97     0.0
# 3           99               México                 97   97     0.0
# 4           99               México                 97   97     0.0
# ...        ...                  ...                ...  ...     ...
# 19995       99               México                 97   97     0.0
# 19996       99               México                 97   97     0.0
# 19997       99               México                 97   97     0.0
# 19998       99               México                 97   97     0.0
# 19999       99               México                 97   97     0.0
#
# [20000 rows x 34 columns]

# %%
# pick columns(features and targets) for ml_model
ml_col = [
    'SEX',
    'Target',
    'PNEUMONIA',
     'AGE',
     'DIABETES',
     'COPD',
     'ASTHMA',
     'CARDIOVASCULAR',
     'OBESITY',
     'RENAL_CHRONIC',
     'SMOKING',
     'FINAL_CLASSIFICATION'
]
ml_df = sample_df.loc[:,ml_col]

# %%
ml_df.groupby(['FINAL_CLASSIFICATION']).count()
# Out:
#                         SEX  Target  PNEUMONIA    AGE  DIABETES   COPD  \
# FINAL_CLASSIFICATION
# 1                       371     371        371    371       371    371
# 2                         3       3          3      3         3      3
# 3                      7147    7147       7147   7147      7147   7147
# 6                        17      17         17     17        17     17
# 7                     12462   12462      12462  12462     12462  12462
#
#                       ASTHMA  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  SMOKING
# FINAL_CLASSIFICATION
# 1                        371             371      371            371      371
# 2                          3               3        3              3        3
# 3                       7147            7147     7147           7147     7147
# 6                         17              17       17             17       17
# 7                      12462           12462    12462          12462    12462

# %%
# drop those whose result are not clear; Add one column "COVID_RESULT": Negative as 0, positive as 1
ml_clean_df = ml_df.loc[ml_df['FINAL_CLASSIFICATION'] != 6]
ml_clean_df.loc[ml_clean_df['FINAL_CLASSIFICATION'] == 7, 'COVID_RESULT'] = int(0)
ml_clean_df.loc[ml_clean_df['FINAL_CLASSIFICATION'] <= 3, 'COVID_RESULT'] = int(1)
# Out:
# C:\Users\yuanj\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\yuanj\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
ml_clean_df = ml_clean_df.drop(columns = 'FINAL_CLASSIFICATION')

# %%
ml_clean_df['Target'] = ml_clean_df['Target'].astype(int)
ml_clean_df['COVID_RESULT'] = ml_clean_df['COVID_RESULT'].astype(int)

# %%
ml_clean_df
# Out:
#        SEX  Target  PNEUMONIA  AGE  DIABETES  COPD  ASTHMA  CARDIOVASCULAR  \
# 0        1       1          1   50         2     2       2               2
# 1        1       0          2    9         2     2       1               2
# 2        2       0          2   47         2     2       2               2
# 3        1       0          2   59         2     2       2               2
# 4        1       0          2   21         2     2       2               2
# ...    ...     ...        ...  ...       ...   ...     ...             ...
# 19995    1       0          2   36         2     2       2               2
# 19996    1       0          2   29         2     2       2               2
# 19997    2       0          2   71         2     2       2               1
# 19998    1       0          2   48         2     2       2               2
# 19999    2       0          2   38         2     2       2               2
#
#        OBESITY  RENAL_CHRONIC  SMOKING  COVID_RESULT
# 0            2              2        2             0
# 1            2              2        2             0
# 2            1              2        2             0
# 3            2              2        2             0
# 4            2              2        2             0
# ...        ...            ...      ...           ...
# 19995        2              2        2             1
# 19996        2              2        2             1
# 19997        2              2        2             0
# 19998        1              2        2             1
# 19999        2              2        2             1
#
# [19983 rows x 12 columns]

# %%
ml_clean_df.dtypes
# Out:
# SEX               int64
# Target            int32
# PNEUMONIA         int64
# AGE               int64
# DIABETES          int64
# COPD              int64
# ASTHMA            int64
# CARDIOVASCULAR    int64
# OBESITY           int64
# RENAL_CHRONIC     int64
# SMOKING           int64
# COVID_RESULT      int32
# dtype: object

# %%
y = ml_clean_df['Target']
X = ml_clean_df.drop(columns = 'Target')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state=1)

# # Creating StandardScaler instance
# scaler = StandardScaler()

# # Fitting Standard Scaler
# X_scaler = scaler.fit(X_train)

# # Scaling data
# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
eec = EasyEnsembleClassifier(random_state=1,n_estimators = 100)
eec.fit(X_train,y_train)
# Out:
# EasyEnsembleClassifier(n_estimators=100, random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred_eec = eec.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred_eec)
# Out:
# 0.9112952232899943

# %%
# Display the confusion matrix
confusion_matrix(y_test,y_pred_eec)
# Out:
# array([[4477,  403],
#        [  11,  105]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred_eec))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      0.92      0.91      0.96      0.91      0.83      4880
#           1       0.21      0.91      0.92      0.34      0.91      0.83       116
#
# avg / total       0.98      0.92      0.91      0.94      0.91      0.83      4996

# %% [markdown]
# ## Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)

# %%
# Undersample the data using `RandomUnderSampler`
from imblearn.under_sampling import RandomUnderSampler
ros = RandomUnderSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)
Counter(y_resampled)
# Out:
# Counter({0: 412, 1: 412})

# %%
classifier.fit(X_resampled, y_resampled)
# Out:
# C:\Users\yuanj\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression(max_iter=200, random_state=1)

# %%
y_pred_log = classifier.predict(X_test)
confusion_matrix(y_test, y_pred_log)
# Out:
# array([[4519,  361],
#        [  17,   99]], dtype=int64)

# %%
balanced_accuracy_score(y_test, y_pred_log)
# Out:
# 0.8897364330130018

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred_log))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      0.93      0.85      0.96      0.89      0.80      4880
#           1       0.22      0.85      0.93      0.34      0.89      0.78       116
#
# avg / total       0.98      0.92      0.86      0.95      0.89      0.80      4996
