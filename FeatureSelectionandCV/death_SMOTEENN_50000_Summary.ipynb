# %%
# Import libraries

# Pandas
import pandas as pd
from collections import Counter

import matplotlib.pyplot as plt
import numpy as np


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.metrics import confusion_matrix


from sklearn.linear_model import LogisticRegression

from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score
from imblearn.metrics import classification_report_imbalanced
from sklearn.metrics import classification_report
from imblearn.ensemble import EasyEnsembleClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

from sklearn.svm import SVC
import sklearn as skl
import tensorflow as tf

# %%
file = '../clean_ml_data_0625.csv'
clean_df = pd.read_csv(file)

# %%
clean_df = clean_df.sample(50000)

# %%
clean_df.head()
# Out:
#          gender  pneumonia  pregnant  diabetes  copd  asthma  immunosup  \
# 1380983       0          0         0         0     0       0          0
# 715230        0          0         0         0     0       0          0
# 175886        0          0         0         0     0       0          0
# 990306        0          0         0         0     0       0          0
# 311103        1          0         0         0     0       0          0
#
#          hypertension  cardiovascular  obesity  renal_chronic  tobacco  \
# 1380983             0               0        0              0        0
# 715230              1               1        0              0        0
# 175886              0               0        0              0        0
# 990306              0               0        0              0        0
# 311103              0               0        0              0        0
#
#          closed_contact  another_complication  death  intubation  ICU  new_age
# 1380983               0                     0      0           0    0        2
# 715230                1                     0      0           0    1        5
# 175886                0                     0      0           0    0        4
# 990306                0                     0      0           0    0        3
# 311103                0                     0      0           0    0        3

# %%
Counter(clean_df.death)
# Out:
# Counter({0: 44908, 1: 5092})

# %%
y= clean_df['death']
X = clean_df.drop(columns = ['ICU','intubation','death'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state =42, stratify=y)

# %%
# Creating StandardScaler instance
scaler = StandardScaler()
# Fitting standard scaler
X_scaler = scaler.fit(X_train)

# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# # Resample the training data with SMOTE
# from imblearn.over_sampling import SMOTE
# X_resampled_s, y_resampled_s = SMOTE(random_state=1,
# sampling_strategy='auto').fit_resample(X_train_scaled,y_train)
# Counter(y_resampled_s)

# %%
# Use SMOTEENN resampling method
from imblearn.combine import SMOTEENN 
smote_enn = SMOTEENN(random_state=0)
X_resampled_s, y_resampled_s = smote_enn.fit_resample(X_train_scaled,y_train)
Counter(y_resampled_s)
# Out:
# Counter({0: 30084, 1: 10721})

# %%
# keep_col = ['gender',
#          'pneumonia', 'new_age',
#        'pregnant', 'diabetes', 'copd',
#        'asthma', 'immunosup', 'hypertension',
#        'cardiovascular', 'obesity', 'renal_chronic', 'tobacco', 'another_complication', 'closed_contact']

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
ml = {
    "Support Vector Machines": SVC(kernel='linear'),
    "LogisticRegression": LogisticRegression(max_iter=1000,solver='lbfgs', random_state=1),
    "Random Forest_2": RandomForestClassifier(n_estimators = 13, random_state = 42, max_depth = 2),
    "Random Forest_4": RandomForestClassifier(n_estimators = 13, random_state = 42, max_depth = 4),
    "Random Forest_6": RandomForestClassifier(n_estimators = 13, random_state = 42, max_depth = 6),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "GradientBoostingClassifier":  GradientBoostingClassifier(n_estimators=20,
                                        learning_rate=1,
                                        max_features=5,
                                        max_depth=3,
                                        random_state=0),
    "KNN": KNeighborsClassifier(n_neighbors=3)
}

results = []
for x in ml:
    model = ml[x]
    model.fit(X_resampled_s, y_resampled_s)
    y_pred_s = model.predict(X_test_scaled)
    accuracy = model.score(X_test_scaled, y_test)
    balanced_accuracy = balanced_accuracy_score(y_test,y_pred_s)
    #calculating precision and reall
    precision = precision_score(y_test, y_pred_s)
    recall = recall_score(y_test, y_pred_s)
    print(f'model{x}: {confusion_matrix(y_test,y_pred_s)}')
    results.append({
    "name": x,
    "Accuracy":accuracy,
    "Balanced_Accuracy":balanced_accuracy,
    "Precision": precision,
    "Recall": recall
})
pd.DataFrame(results).sort_values("Accuracy", ascending=False)
# Out:
# modelSupport Vector Machines: [[10231   996]
#  [  336   937]]
# modelLogisticRegression: [[10188  1039]
#  [  300   973]]
# modelRandom Forest_2: [[10514   713]
#  [  435   838]]
# modelRandom Forest_4: [[10397   830]
#  [  367   906]]
# modelRandom Forest_6: [[10286   941]
#  [  334   939]]
# modelDecision Tree: [[10488   739]
#  [  454   819]]
# modelGradientBoostingClassifier: [[10494   733]
#  [  420   853]]
# modelKNN: [[10314   913]
#  [  507   766]]
#                          name  Accuracy  Balanced_Accuracy  Precision  \
# 2             Random Forest_2   0.90816           0.797390   0.540297
# 6  GradientBoostingClassifier   0.90776           0.802391   0.537831
# 5               Decision Tree   0.90456           0.788769   0.525674
# 3             Random Forest_4   0.90424           0.818888   0.521889
# 4             Random Forest_6   0.89800           0.826906   0.499468
# 0     Support Vector Machines   0.89344           0.823671   0.484739
# 1          LogisticRegression   0.89288           0.835896   0.483598
# 7                         KNN   0.88640           0.760203   0.456224
#
#      Recall
# 2  0.658288
# 6  0.670071
# 5  0.643362
# 3  0.711705
# 4  0.737628
# 0  0.736057
# 1  0.764336
# 7  0.601728

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
BE = {
    "Balanced Random Forest": BalancedRandomForestClassifier(n_estimators=100, random_state=42),
    "Easy Ensemble": EasyEnsembleClassifier(random_state=42,n_estimators = 100)
}

results = []
for x in BE:
    model2 = BE[x]
    model2.fit(X_train_scaled, y_train)
    y_pred_s2 = model2.predict(X_test_scaled)
    accuracy = model2.score(X_test_scaled, y_test)
    balanced_accuracy = balanced_accuracy_score(y_test,y_pred_s2)
    #calculating precision and reall
    precision = precision_score(y_test, y_pred_s2)
    recall = recall_score(y_test, y_pred_s2)
    print(f'model{x}: {confusion_matrix(y_test,y_pred_s2)}')
    results.append({
    "name": x,
    "Accuracy":accuracy,
    "Balanced_Accuracy":balanced_accuracy,
    "Precision": precision,
    "Recall": recall
})
pd.DataFrame(results).sort_values("Accuracy", ascending=False)
# Out:
# modelBalanced Random Forest: [[9511 1716]
#  [ 152 1121]]
# modelEasy Ensemble: [[9835 1392]
#  [ 200 1073]]
#                      name  Accuracy  Balanced_Accuracy  Precision    Recall
# 1           Easy Ensemble   0.87264           0.859452   0.435294  0.842891
# 0  Balanced Random Forest   0.85056           0.863876   0.395136  0.880597

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_of_features = len(X_resampled_s[0])
first_layer_unit = 80
second_layer_unit = 30
first_activation = 'relu'
second_activation = 'relu'

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units = first_layer_unit,input_dim = number_of_features,activation = first_activation))

# Second hidden layer
nn.add(
    tf.keras.layers.Dense(units = second_layer_unit,activation = second_activation))

# Output layer
nn.add(
    tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                1280
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 3,741
# Trainable params: 3,741
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["Accuracy","TruePositives",'FalseNegatives'])

# %%
# Train the model
fit_model = nn.fit(X_resampled_s, y_resampled_s,epochs = 50)
# Out:
# Epoch 1/50
# 1276/1276 [==============================] - 9s 4ms/step - loss: 0.1164 - Accuracy: 0.9620 - true_positives: 9745.0000 - false_negatives: 976.0000
# Epoch 2/50
# 1276/1276 [==============================] - 5s 4ms/step - loss: 0.0881 - Accuracy: 0.9693 - true_positives: 9864.0000 - false_negatives: 857.0000
# Epoch 3/50
# 1276/1276 [==============================] - 5s 4ms/step - loss: 0.0812 - Accuracy: 0.9724 - true_positives: 9936.0000 - false_negatives: 785.0000
# Epoch 4/50
# 1276/1276 [==============================] - 5s 4ms/step - loss: 0.0774 - Accuracy: 0.9747 - true_positives: 9987.0000 - false_negatives: 734.0000
# Epoch 5/50
# 1276/1276 [==============================] - 4s 3ms/step - loss: 0.0733 - Accuracy: 0.9757 - true_positives: 10009.0000 - false_negatives: 712.0000
# Epoch 6/50
# 1276/1276 [==============================] - 4s 3ms/step - loss: 0.0704 - Accuracy: 0.9762 - true_positives: 10021.0000 - false_negatives: 700.0000
# Epoch 7/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0681 - Accuracy: 0.9776 - true_positives: 10046.0000 - false_negatives: 675.0000
# Epoch 8/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0658 - Accuracy: 0.9779 - true_positives: 10059.0000 - false_negatives: 662.0000
# Epoch 9/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0630 - Accuracy: 0.9786 - true_positives: 10071.0000 - false_negatives: 650.0000
# Epoch 10/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0618 - Accuracy: 0.9796 - true_positives: 10096.0000 - false_negatives: 625.0000
# Epoch 11/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0601 - Accuracy: 0.9805 - true_positives: 10118.0000 - false_negatives: 603.0000
# Epoch 12/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0582 - Accuracy: 0.9809 - true_positives: 10107.0000 - false_negatives: 614.0000
# Epoch 13/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0568 - Accuracy: 0.9812 - true_positives: 10127.0000 - false_negatives: 594.0000
# Epoch 14/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0553 - Accuracy: 0.9817 - true_positives: 10138.0000 - false_negatives: 583.0000
# Epoch 15/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0538 - Accuracy: 0.9825 - true_positives: 10154.0000 - false_negatives: 567.0000
# Epoch 16/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0529 - Accuracy: 0.9823 - true_positives: 10153.0000 - false_negatives: 568.0000
# Epoch 17/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0513 - Accuracy: 0.9828 - true_positives: 10164.0000 - false_negatives: 557.0000
# Epoch 18/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0506 - Accuracy: 0.9833 - true_positives: 10186.0000 - false_negatives: 535.0000
# Epoch 19/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0486 - Accuracy: 0.9837 - true_positives: 10183.0000 - false_negatives: 538.0000
# Epoch 20/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0474 - Accuracy: 0.9843 - true_positives: 10210.0000 - false_negatives: 511.0000
# Epoch 21/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0465 - Accuracy: 0.9842 - true_positives: 10209.0000 - false_negatives: 512.0000
# Epoch 22/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0454 - Accuracy: 0.9846 - true_positives: 10234.0000 - false_negatives: 487.0000
# Epoch 23/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0437 - Accuracy: 0.9857 - true_positives: 10241.0000 - false_negatives: 480.0000
# Epoch 24/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0429 - Accuracy: 0.9862 - true_positives: 10254.0000 - false_negatives: 467.0000
# Epoch 25/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0418 - Accuracy: 0.9859 - true_positives: 10263.0000 - false_negatives: 458.0000
# Epoch 26/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0402 - Accuracy: 0.9867 - true_positives: 10282.0000 - false_negatives: 439.0000
# Epoch 27/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0401 - Accuracy: 0.9865 - true_positives: 10281.0000 - false_negatives: 440.0000
# Epoch 28/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0379 - Accuracy: 0.9874 - true_positives: 10301.0000 - false_negatives: 420.0000
# Epoch 29/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0375 - Accuracy: 0.9872 - true_positives: 10299.0000 - false_negatives: 422.0000
# Epoch 30/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0357 - Accuracy: 0.9883 - true_positives: 10331.0000 - false_negatives: 390.0000
# Epoch 31/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0347 - Accuracy: 0.9885 - true_positives: 10344.0000 - false_negatives: 377.0000
# Epoch 32/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0347 - Accuracy: 0.9887 - true_positives: 10341.0000 - false_negatives: 380.0000
# Epoch 33/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0335 - Accuracy: 0.9888 - true_positives: 10353.0000 - false_negatives: 368.0000
# Epoch 34/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0329 - Accuracy: 0.9895 - true_positives: 10362.0000 - false_negatives: 359.0000
# Epoch 35/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0315 - Accuracy: 0.9899 - true_positives: 10378.0000 - false_negatives: 343.0000
# Epoch 36/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0310 - Accuracy: 0.9898 - true_positives: 10383.0000 - false_negatives: 338.0000
# Epoch 37/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0310 - Accuracy: 0.9898 - true_positives: 10386.0000 - false_negatives: 335.0000
# Epoch 38/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0295 - Accuracy: 0.9901 - true_positives: 10388.0000 - false_negatives: 333.0000
# Epoch 39/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0290 - Accuracy: 0.9903 - true_positives: 10400.0000 - false_negatives: 321.0000
# Epoch 40/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0276 - Accuracy: 0.9907 - true_positives: 10420.0000 - false_negatives: 301.0000
# Epoch 41/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0280 - Accuracy: 0.9907 - true_positives: 10411.0000 - false_negatives: 310.0000
# Epoch 42/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0270 - Accuracy: 0.9911 - true_positives: 10429.0000 - false_negatives: 292.0000
# Epoch 43/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0263 - Accuracy: 0.9911 - true_positives: 10431.0000 - false_negatives: 290.0000
# Epoch 44/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0255 - Accuracy: 0.9912 - true_positives: 10433.0000 - false_negatives: 288.0000
# Epoch 45/50
# 1276/1276 [==============================] - 3s 2ms/step - loss: 0.0250 - Accuracy: 0.9917 - true_positives: 10443.0000 - false_negatives: 278.0000
# Epoch 46/50
# 1276/1276 [==============================] - 4s 3ms/step - loss: 0.0245 - Accuracy: 0.9920 - true_positives: 10465.0000 - false_negatives: 256.0000
# Epoch 47/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0241 - Accuracy: 0.9919 - true_positives: 10463.0000 - false_negatives: 258.0000
# Epoch 48/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0229 - Accuracy: 0.9924 - true_positives: 10465.0000 - false_negatives: 256.0000
# Epoch 49/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0227 - Accuracy: 0.9923 - true_positives: 10474.0000 - false_negatives: 247.0000
# Epoch 50/50
# 1276/1276 [==============================] - 3s 3ms/step - loss: 0.0226 - Accuracy: 0.9927 - true_positives: 10488.0000 - false_negatives: 233.0000

# %%
# Evaluate the model using the test data : Recall: tp/(tp+fn) 0.829236
results = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(results)
# print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 391/391 - 2s - loss: 1.2697 - Accuracy: 0.8942 - true_positives: 899.0000 - false_negatives: 374.0000 - 2s/epoch - 5ms/step
# [1.2696738243103027, 0.8941599726676941, 899.0, 374.0]

# %%
# #Plotting Precision-Recall Curve
# disp = plot_precision_recall_curve(model, X_test_scaled, y_test)

# %%
# # # Create a method that creates a new Sequential model with hyperparameter options
# def create_model(hp):
#     nn_model = tf.keras.models.Sequential()

#     # Allow kerastuner to decide which activation function to use in hidden layers
#     activation = hp.Choice('activation',['relu','tanh','sigmoid'])
#     first_units = hp.Int('first_units', min_value=1, max_value=10, step=2)
    
#     # Allow kerastuner to decide number of neurons in first layer
#     nn_model.add(tf.keras.layers.Dense(units=first_units, activation=activation, input_dim=len(X_train_scaled[0])))

#     # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
#     for i in range(hp.Int('num_layers', 1, 6)):
#         next_units = hp.Int('units_' + str(i), min_value=1, max_value=10, step=2)

#         nn_model.add(tf.keras.layers.Dense(units=next_units, activation=activation))
    
#     nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

#     # Compile the model
#     nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["Accuracy"])

#     return nn_model

# %%
# import keras_tuner as kt

# tuner = kt.Hyperband(
#     create_model, # function name
#     objective="val_accuracy",
#     max_epochs=20,
#     hyperband_iterations=2)

# %%
# # Run the kerastuner search for best hyperparameters
# tuner.search(X_resampled_s, y_resampled_s,epochs=20,validation_data=(X_test_scaled,y_test))

# %%
# # Get best model hyperparameters
# best_hyper = tuner.get_best_hyperparameters(1)[0]
# best_hyper.values

# %%
# best_model = tuner.get_best_models(1)[0]
# fit_model = best_model.fit(X_resampled_s, y_resampled_s, epochs=20)

# %%
# # Evaluate best model against full test data
# model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
# print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# import numpy as np
# from sklearn.feature_selection import SelectKBest, chi2, f_classif

# # Perform feature selection
# selector = SelectKBest(f_classif, k=10)
# selector.fit(X, y)

# # Get the raw p-values for each feature, and transform from p-values into scores
# scores = -np.log10(selector.pvalues_)

# # Plot the scores.
# plt.bar(range(len(keep_col)), scores)
# plt.xticks(range(len(keep_col)), X, rotation='vertical')
# plt.show()
